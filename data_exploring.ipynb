# %%
import pandas as pd

# %%
data_2019_q1 = pd.read_csv("./data/2019/2019 Q1 (Jan-Mar)-Central.csv")
data_2019_q1
# Out:
#                     Wave  SiteID        Date Weather      Time      Day Round  \
# 0      2019 Q1 (Jan-Mar)  ML0001  25/02/2019     Dry  06:00:00  Weekday     A
# 1      2019 Q1 (Jan-Mar)  ML0001  25/02/2019     Dry  06:15:00  Weekday     A
# 2      2019 Q1 (Jan-Mar)  ML0001  25/02/2019     Dry  06:30:00  Weekday     A
# 3      2019 Q1 (Jan-Mar)  ML0001  25/02/2019     Dry  06:45:00  Weekday     A
# 4      2019 Q1 (Jan-Mar)  ML0001  25/02/2019     Dry  07:00:00  Weekday     A
# ...                  ...     ...         ...     ...       ...      ...   ...
# 53499  2019 Q1 (Jan-Mar)  ML0104  19/03/2019     Dry  20:45:00  Weekday     A
# 53500  2019 Q1 (Jan-Mar)  ML0104  19/03/2019     Dry  21:00:00  Weekday     A
# 53501  2019 Q1 (Jan-Mar)  ML0104  19/03/2019     Dry  21:15:00  Weekday     A
# 53502  2019 Q1 (Jan-Mar)  ML0104  19/03/2019     Dry  21:30:00  Weekday     A
# 53503  2019 Q1 (Jan-Mar)  ML0104  19/03/2019     Dry  21:45:00  Weekday     A
#
#         Direction Path              Mode  Count
# 0      Northbound  NaN    Private cycles     14
# 1      Northbound  NaN    Private cycles     32
# 2      Northbound  NaN    Private cycles     63
# 3      Northbound  NaN    Private cycles     71
# 4      Northbound  NaN    Private cycles    102
# ...           ...  ...               ...    ...
# 53499  Southbound  NaN  Cycle hire bikes      0
# 53500  Southbound  NaN  Cycle hire bikes      0
# 53501  Southbound  NaN  Cycle hire bikes      1
# 53502  Southbound  NaN  Cycle hire bikes      0
# 53503  Southbound  NaN  Cycle hire bikes      0
#
# [53504 rows x 11 columns]

# %%
print(pd.io.sql.get_schema(data_2019_q1, "2019_q1"))
# Out:
# CREATE TABLE "2019_q1" (
# "Wave" TEXT,
#   "SiteID" TEXT,
#   "Date" TEXT,
#   "Weather" TEXT,
#   "Time" TEXT,
#   "Day" TEXT,
#   "Round" TEXT,
#   "Direction" TEXT,
#   "Path" TEXT,
#   "Mode" TEXT,
#   "Count" INTEGER
# )

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType, DateType
from pyspark.sql import functions as F

spark = SparkSession.builder.master("local[*]").appName("SparkProcessing").getOrCreate()
# Out:
# +-----------------+------+----+-------+--------+-------+-----+----------+----+--------------+-----+
# |             Wave|SiteID|Date|Weather|    Time|    Day|Round| Direction|Path|          Mode|Count|
# +-----------------+------+----+-------+--------+-------+-----+----------+----+--------------+-----+
# |2019 Q1 (Jan-Mar)|ML0001|NULL|    Dry|06:00:00|Weekday|    A|Northbound| n/a|Private cycles|   14|
# |2019 Q1 (Jan-Mar)|ML0001|NULL|    Dry|06:15:00|Weekday|    A|Northbound| n/a|Private cycles|   32|
# |2019 Q1 (Jan-Mar)|ML0001|NULL|    Dry|06:30:00|Weekday|    A|Northbound| n/a|Private cycles|   63|
# |2019 Q1 (Jan-Mar)|ML0001|NULL|    Dry|06:45:00|Weekday|    A|Northbound| n/a|Private cycles|   71|
# |2019 Q1 (Jan-Mar)|ML0001|NULL|    Dry|07:00:00|Weekday|    A|Northbound| n/a|Private cycles|  102|
# +-----------------+------+----+-------+--------+-------+-----+----------+----+--------------+-----+
# only showing top 5 rows

# %%
schema = StructType([
            StructField("Wave", StringType(), True),
            StructField("SiteID", StringType(), True),
            StructField("Date", StringType(), True),
            StructField("Weather", StringType(), True),
            StructField("Time", StringType(), True),
            StructField("Day", StringType(), True),
            StructField("Round", StringType(), True),
            StructField("Direction", StringType(), True),
            StructField("Path", StringType(), True),
            StructField("Mode", StringType(), True),
            StructField("Count", IntegerType(), True)
        ])

df = spark.read.csv("./data/2019/2019 Q1 (Jan-Mar)-Central.csv", header=True, schema=schema)
df = df.withColumn("Date", F.to_date("Date", "dd/MM/yyyy"))
df.show(5)
df.printSchema()

# %%
df_W = spark.read.csv("./2022 W1 spring-Central.csv", header=True, schema=schema)
df_W = df_W.withColumn("Date", F.to_date("Date", "dd/MM/yyyy"))
df_W.show(5)
# Out:
# +--------------+------+----------+-------+--------+-------+-----+----------+-----------+-----------+-----+
# |          Wave|SiteID|      Date|Weather|    Time|    Day|Round| Direction|       Path|       Mode|Count|
# +--------------+------+----------+-------+--------+-------+-----+----------+-----------+-----------+-----+
# |2022 W1 spring|ML0001|2022-07-13|    Dry|06:00:00|Weekday|    A|Northbound|Carriageway|Cargo bikes|    0|
# |2022 W1 spring|ML0001|2022-07-13|    Dry|06:15:00|Weekday|    A|Northbound|Carriageway|Cargo bikes|    0|
# |2022 W1 spring|ML0001|2022-07-13|    Dry|06:30:00|Weekday|    A|Northbound|Carriageway|Cargo bikes|    0|
# |2022 W1 spring|ML0001|2022-07-13|    Dry|06:45:00|Weekday|    A|Northbound|Carriageway|Cargo bikes|    0|
# |2022 W1 spring|ML0001|2022-07-13|    Dry|07:00:00|Weekday|    A|Northbound|Carriageway|Cargo bikes|    0|
# +--------------+------+----------+-------+--------+-------+-----+----------+-----------+-----------+-----+
# only showing top 5 rows
